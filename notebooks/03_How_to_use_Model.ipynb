# %%
# Import the custom preprocessing module.
import PreProcessing_PD_Model as prepro

# %%
# Read the credit risk dataset into a pandas DataFrame.
df = prepro.pd.read_csv("credit_risk_dataset.csv")

# %%
# Display the first five rows of the DataFrame to inspect the data.
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
# Call a custom function to preprocess the data, returning scaled features, original features, target, and balanced data.
data_to_scale, features, target, balanced_features, balanced_target = prepro.ModelPreProcessing(df)
data_to_scale, features, target, balanced_features, balanced_target = prepro.ModelPreProcessing(df)

# %%
# Display the first five rows of the numerical data before scaling.
data_to_scale.head()
# Out:
#    person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0          21           9600                5.0       1000          11.14
# 1          25           9600                1.0       5500          12.87
# 2          23          65500                4.0      35000          15.23
# 3          24          54400                8.0      35000          14.27
# 4          21           9900                2.0       2500           7.14
#
#    loan_percent_income  cb_person_cred_hist_length
# 0                 0.10                           2
# 1                 0.57                           3
# 2                 0.53                           2
# 3                 0.55                           4
# 4                 0.25                           2

# %%
# Display the first five rows of the balanced, preprocessed feature set with both numerical and one-hot encoded categorical columns.
balanced_features.head()
# Out:
#    person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0   -1.090587      -1.078051           0.054432  -1.367192       0.034115
# 1   -0.441211      -1.078051          -0.938456  -0.656810       0.597575
# 2   -0.765899      -0.018803          -0.193790   4.000141       1.366226
# 3   -0.603555      -0.229137           0.799097   4.000141       1.053554
# 4   -1.090587      -1.072366          -0.690234  -1.130398      -1.268682
#
#    loan_percent_income  cb_person_cred_hist_length  OTHER  OWN  RENT  \
# 0            -0.655113                   -0.939656      0    1     0
# 1             3.767461                   -0.692664      0    0     0
# 2             3.391072                   -0.939656      0    0     1
# 3             3.579267                   -0.445671      0    0     1
# 4             0.756347                   -0.939656      0    1     0
#
#    EDUCATION  HOMEIMPROVEMENT  MEDICAL  PERSONAL  VENTURE  \
# ...

# %%
# Import the pickle library to handle serialization of Python objects.
import pickle

# %%
# Load the pre-trained Logistic Regression model from a pickle file.
with open('logisticPDmodel.pkl','rb') as file:
    logisticPDmodel = pickle.load(file)

# %%
# Load the pre-trained Random Forest model from a pickle file.
with open('RandomForestPDmodel.pkl','rb') as file:
    RandomForestPDmodel = pickle.load(file)

# %%
# Load the pre-trained XGBoost model from a pickle file.
with open('XGBPDmodel.pkl','rb') as file:
    XGBPDmodel = pickle.load(file)

# %%
# Example: Use the loaded Logistic Regression model to make predictions on the preprocessed features.
logistic_pred = logisticPDmodel.predict(features)

# %%
# Import the classification_report function and print the performance report for the Logistic Regression model.
from sklearn.metrics import classification_report
print(classification_report(target, logistic_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85     24846
#            1       0.49      0.76      0.59      6825
#
#     accuracy                           0.78     31671
#    macro avg       0.70      0.77      0.72     31671
# weighted avg       0.83      0.78      0.79     31671
